# %% [markdown]
# # Example Usage
#
# This is a basic example using the torchvision COCO dataset from coco.py, it assumes that you've already downloaded the COCO images and annotations JSON.  You'll notice that the scale augmentations are quite extreme.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import cv2
import numpy as np
from copy_paste import CopyPaste
from coco import CocoDetectionCP
from visualize import display_instances
import albumentations as A
import random
from matplotlib import pyplot as plt
import os

# %%
transform = A.Compose([
        A.RandomScale(scale_limit=(-0.9, 1), p=1), #LargeScaleJitter from scale of 0.1 to 2
        A.PadIfNeeded(256, 256, border_mode=0), #pads with image in the center, not the top left like the paper
        A.RandomCrop(256, 256),
        CopyPaste(blend=True, sigma=1, pct_objects_paste=0.8, p=1.) #pct_objects_paste is a guess
    ], bbox_params=A.BboxParams(format="coco", min_visibility=0.05)
)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Andreas\\Documents\\DTU filer\\0 Specialkursus - DL & CV\\Exercises\\project\\src\\copy-paste'

# %%
data = CocoDetectionCP(
    '../../data/coco_minitrain_25k/images/train2017', 
    '../../data/coco_minitrain_25k/annotations/instances_val2017.json', 
    transform
)
# Out:
# loading annotations into memory...
# Done (t=1.05s)
# creating index...
# index created!

# %%
f, ax = plt.subplots(1, 2, figsize=(16, 16))

index = random.randint(0, len(data))
img_data = data[index]
image = img_data['image']
masks = img_data['masks']
bboxes = img_data['bboxes']
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[20], line 4
#       1 f, ax = plt.subplots(1, 2, figsize=(16, 16))
#       3 index = random.randint(0, len(data))
# ----> 4 img_data = data[index]
#       5 image = img_data['image']
#       6 masks = img_data['masks']
#
# File ~\Documents\DTU filer\0 Specialkursus - DL & CV\Exercises\project\src\copy-paste\copy_paste.py:300, in copy_paste_class.<locals>.__getitem__(self, idx)
#     297 if not hasattr(self, 'post_transforms'):
#     298     self._split_transforms()
# --> 300 img_data = self.load_example(idx)
#     301 if self.copy_paste is not None:
#     302     paste_idx = random.randint(0, self.__len__() - 1)
#
# File ~\Documents\DTU filer\0 Specialkursus - DL & CV\Exercises\project\src\copy-paste\coco.py:60, in CocoDetectionCP.load_example(self, index)
#      58 path = self.coco.loadImgs(img_id)[0]['file_name']
#      59 image = cv2.imread(os.path.join(self.root, path))
# ---> 60 image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#      62 #convert all of the target segmentations to masks
#      63 #bboxes are expected to be (y1, x1, y2, x2, category_id)
#      64 masks = []
#
# error: OpenCV(4.8.1) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
empty = np.array([])
display_instances(image, empty, empty, empty, empty, show_mask=False, show_bbox=False, ax=ax[0])

if len(bboxes) > 0:
    boxes = np.stack([b[:4] for b in bboxes], axis=0)
    box_classes = np.array([b[-2] for b in bboxes])
    mask_indices = np.array([b[-1] for b in bboxes])
    show_masks = np.stack(masks, axis=-1)[..., mask_indices]
    class_names = {k: data.coco.cats[k]['name'] for k in data.coco.cats.keys()}
    display_instances(image, boxes, show_masks, box_classes, class_names, show_bbox=True, ax=ax[1])
else:
    display_instances(image, empty, empty, empty, empty, show_mask=False, show_bbox=False, ax=ax[1])
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[12], line 4
#       1 f, ax = plt.subplots(1, 2, figsize=(16, 16))
#       3 index = random.randint(0, len(data))
# ----> 4 img_data = data[index]
#       5 image = img_data['image']
#       6 masks = img_data['masks']
#
# File ~\Documents\DTU filer\0 Specialkursus - DL & CV\Exercises\project\src\copy-paste\copy_paste.py:300, in copy_paste_class.<locals>.__getitem__(self, idx)
#     297 if not hasattr(self, 'post_transforms'):
#     298     self._split_transforms()
# --> 300 img_data = self.load_example(idx)
#     301 if self.copy_paste is not None:
#     302     paste_idx = random.randint(0, self.__len__() - 1)
#
# File ~\Documents\DTU filer\0 Specialkursus - DL & CV\Exercises\project\src\copy-paste\coco.py:60, in CocoDetectionCP.load_example(self, index)
#      58 path = self.coco.loadImgs(img_id)[0]['file_name']
#      59 image = cv2.imread(os.path.join(self.root, path))
# ---> 60 image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#      62 #convert all of the target segmentations to masks
#      63 #bboxes are expected to be (y1, x1, y2, x2, category_id)
#      64 masks = []
#
# error: OpenCV(4.8.1) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
